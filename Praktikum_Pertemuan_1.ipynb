# %% [markdown]
# <a href="https://colab.research.google.com/github/awfajri/artificial-intelligence/blob/main/Praktikum_Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Membuat data angka (array)
my_data = np.array([[5.1, 3.5, 1.4, 0.2],
                    [4.9, 3.0, 1.4, 0.2],
                    [4.7, 3.2, 1.3, 0.2],
                    [4.6, 3.1, 1.5, 0.2],
                    [5.0, 3.6, 1.4, 0.2]])

# Membuat nama kolom
column_names = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

# %%
data_frame = pd.DataFrame(data=my_data, columns=column_names)
print(data_frame)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
data_frame ["Species"] = "Iris-setosa"

# %%
print(data_frame)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
